# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python-headless matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    ---------------------------------------- 0.2/39.4 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.7/39.4 MB 9.3 MB/s eta 0:00:05
#    - -------------------------------------- 1.2/39.4 MB 9.4 MB/s eta 0:00:05
#    - -------------------------------------- 1.7/39.4 MB 10.0 MB/s eta 0:00:04
#    -- ------------------------------------- 2.3/39.4 MB 9.9 MB/s eta 0:00:04
#    -- ------------------------------------- 2.9/39.4 MB 10.9 MB/s eta 0:00:04
#    --- ------------------------------------ 3.3/39.4 MB 10.6 MB/s eta 0:00:04
#    --- ------------------------------------ 3.9/39.4 MB 10.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.5/39.4 MB 11.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.1/39.4 MB 11.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.5/39.4 MB 11.0 MB/s eta 0:00:04
# ...

# %%
import cv2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_bgr = cv2.imread('cat.png')
plt.imshow(img_bgr)

# %%
img= cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')

# %%
resized_img = cv2.resize(img,(150,150))
plt.imshow(resized_img)
plt.show()

# %%
img[:,:,1]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
img[:,:,0]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
img[:,:,2]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(img[:,:,0],cmap = 'gray')
plt.show()

# %%
plt.imshow(img[:,:,1],cmap = 'gray')
plt.show()

# %%
plt.imshow(img[:,:,2],cmap = 'gray')
plt.show()

# %%
plt.imshow(img[15:350,53:245])

# %%
img[15:350,104:300] = img[15:350,53:245]

# %%
plt.imshow(img)

# %%
cv2.line(img, (50, 50), (200, 50), (255, 0, 0), 5)
cv2.rectangle(img, (60, 60), (160, 160), (0, 255, 0), 3)
cv2.circle(img, (120, 120), 40, (0, 0, 255))
plt.imshow(img)
plt.show()

# %%
# Apply Gaussian Blur
gaussian_blur = cv2.GaussianBlur(img, (15, 15), 0)
plt.imshow(gaussian_blur)
plt.show()

# %%
gaussian_blur = cv2.GaussianBlur(img, (5, 5), 0)
plt.imshow(gaussian_blur)
plt.show()

# %%
gaussian_blur = cv2.GaussianBlur(img, (1, 1), 0)
plt.imshow(gaussian_blur)
plt.show()

# %%
# Apply Sharpening Filter
kernel_sharpening = np.array([[0, -1, 0],
                              [-1, 5, -1],
                              [0, -1, 0]])
sharpened = cv2.filter2D(img, -1, kernel_sharpening)
plt.imshow(sharpened)

# %%
# Create a Contrast Filter
alpha = 1.23  # Contrast control (1.0-3.0) - increase for higher contrast
beta = 0     # Brightness control (0-100) - adjust if needed

# Apply Contrast Filter
contrast_enhanced = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
plt.imshow(contrast_enhanced)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')
plt.show()

# %%
# Apply Histogram Equalization
equalized_image = cv2.equalizeHist(gray)
plt.imshow(equalized_image,cmap='gray')
plt.show()

# %%
kernel_size = (5, 5)  # Define the kernel size (width, height)
box_filtered = cv2.blur(img, kernel_size)
plt.imshow(box_filtered)
plt.show()

# %%
# Load the image in grayscale
image_path = "cat.png"  # Replace with the path to your image
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

if image is None:
    raise FileNotFoundError("Image not found. Please check the path.")

# Apply Sobel filters to calculate gradients in the x and y directions
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # Gradient in x direction
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)  # Gradient in y direction

# Calculate the gradient magnitude
gradient_magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
# Normalize to 0-255
gradient_magnitude = np.uint8(255 * gradient_magnitude / np.max(gradient_magnitude))

# Display the results
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.title("Sobel X")
plt.imshow(np.abs(sobel_x), cmap='gray')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.title("Sobel Y")
plt.imshow(np.abs(sobel_y), cmap='gray')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.title("Gradient Magnitude")
plt.imshow(gradient_magnitude, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
